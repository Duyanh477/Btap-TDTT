# %% [markdown]
# W2A1

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# W2A2

# %%
ten = str(input())
print(f'Hello {ten}')
# Out:
# Hello Duy

# %% [markdown]
# W2A3

# %%
a = int(input())
b = int(input())
tong = a + b
hieu = a - b
pnguyen = a // b
du = a % b
thuc = a / b
thuc = round(thuc,2)
print(tong, hieu, pnguyen, du, thuc, end ='\t')
# Out:
# 3 -1 0 1 0.5

# %% [markdown]
# W2A4

# %%
a1, b1, c1, a2, b2, a3 = map(int,input().split())
mot = a1 + b1 + c1
hai = (a2 + b2)* 2
ba = a3 * 3
tbc = (mot + hai + ba) / 10 
print(f'{tbc:.1f}')
# Out:
# 4.2

# %% [markdown]
# W2A5

# %%
a, b = map(int,input().split())
print(a ** b)
# Out:
# 8

# %% [markdown]
# W2A6

# %%
a = input()
if len(a) != 1 or 'A' <= a <= 'Z':
    print(f'in lai')
else:
    if 'a' <= a <= 'z':
        vi_tri = ord(a)
        in_hoa = chr(ord(a) - 32)
    print(vi_tri, in_hoa)
# Out:
# 104 H

# %% [markdown]
# W2A7

# %%
A = ((13 ** 2) * 3) + 5  
B = 13**2*3 + 5
print(A, B)
# Out:
# 512 512

# %% [markdown]
# W2A8

# %%
c = int(input())
f = 9/5* c + 32
print(f'{f:.2f}')
# Out:
# 50.00

# %% [markdown]
# W2A9

# %%
x = float(input())
van_chuyen = 10 
vat = 0.1 * x
nhap_canh = 0.3 * x 
tong = x + van_chuyen + vat + nhap_canh
print(f'{tong:.2f}')
# Out:
# 150.00

# %% [markdown]
# W2A10

# %%
a, b ,c = map(str,input().split())
print(f'Hi {c}, {b} and {a}!')
# Out:
# Hi Helen, Alice and Bob!

# %% [markdown]
# W2A11

# %%
a, b = map(int, input().split())
gio = a* 3600
phut = b * 60 
giay = gio + phut
print(giay)
# Out:
# 5400

# %% [markdown]
# W2A12

# %%
n = int(input())
dan = n ** 2 * 6
print(dan)

# %% [markdown]
# W2A13

# %%
a, b = map(int,input().split())
tich = a * b
dvi = tich % 10
print(dvi)
# Out:
# 8

# %% [markdown]
# W2A14

# %%
a,b = map(int,input().split())
a , b = b , a
print(a,b )
# Out:
# 9 10

# %% [markdown]
# W2A15

# %%
n = int(input())
print(6 * n * (n - 1) + 1)

# %% [markdown]
# W2A16

# %%
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# W2A17

# %%
print("  * ")
print(" * * ")
print("* * * ")
# Out:
#   *
#  * *
# * * *

# %% [markdown]
# W2A18

# %%
print("### # #   ### ###")
print(" #  #  #   #   #")
print(" #  #   #  #   #")
print(" #  #  #   #   #")
print(" #  ##     #   #")
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  ##     #   #

# %% [markdown]
# W2A19

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# W2A20

# %%
print('''January
February
March
April
May
June
July
August
September
October
November
December''')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# W2A21

# %%
a = "Hello World!"
i = 0
while i < 10:
    print(a)
    i += 1
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
